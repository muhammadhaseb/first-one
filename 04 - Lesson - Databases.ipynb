# %% [markdown]
# # Databases

# %% [markdown]
# ![Data Science Workflow](img/ds-workflow.png)

# %% [markdown]
# ## Acquire Data
# ### Common Data Sources
# - The Internet - Web Scraping
# - **Databases**
# - CSV
# - Excel
# - Parquet

# %% [markdown]
# ### Database
# - **Relational databases** models data in rows and columns in a series of tables.
# - Like a collection of **DataFrames/Excel sheets**.
# - **SQL** (often pronounced *sequel*): Structured Query Language
# - Non-relational databases [NoSQL](https://en.wikipedia.org/wiki/NoSQL)

# %% [markdown]
# ### SQLite database
# - [SQLite database](https://www.sqlite.org/index.html) software library that provides a relational database management system
# - Lightweight to setup, administrate, and requires low resources.

# %% [markdown]
# ### Dataset (in a SQLite database)
# - Dallas Police Officer-Involved Shootings
# - Has three tables: **incidents, officers, subjects**
#
# #### Other SQLite datasets
# - [SQLite Data Starter Packs](http://2016.padjo.org/tutorials/sqlite-data-starterpacks/)
# - [Iris Species (Kaggle)](https://www.kaggle.com/uciml/iris)
# - [European Soccer Database (Kaggle)](https://www.kaggle.com/hugomathien/soccer)

# %% [markdown]
# ### Database connector
# - The [sqlite3](https://docs.python.org/3/library/sqlite3.html) is an interface for SQLite databases.
# - No installation needed.
#
# #### Other database connectors for Python
# * [MySQL Connector](https://dev.mysql.com/doc/connector-python/en/) for MySQL
# * [Psycopg](http://initd.org/psycopg/docs/install.html) for PostgreSQL
# * [pymssql](http://pymssql.org/en/stable/) for Microsoft MS SQL

# %% [markdown]
# To import and connect to a SQLite database.
# ```Python
# import sqlite3
# conn = sqlite3.connect('files/dallas-ois.sqlite')
# ```

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sqlite3 as sq

# %%
conn=sq.connect('files/dallas-ois.sqlite')

# %% [markdown]
# The interface to the datases is through the `cursor`.
#
# ```Python
# cursor = conn.cursor()
# ```
#
# The `execute` method allows to run `SQL` queries on our database.
#
# To get a list of all the tables the following query can be applied.
#
# ```SQL
# SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# ```
#
# The result is fetched with the `fetchall()` method.

# %% [markdown]
# To get a description of a table (SQLite specific)
#
# ```SQL
# PRAGMA table_info(officers)
# ```

# %% [markdown]
# ### SQL syntax
# Get all data from table
# ```SQL
# SELECT * FROM table_name
# ```
#
# Limit the response
# ```SQL
# SELECT * FROM table_name LIMIT 100
# ```
#
# Filter data
# ```SQL
# SELECT * FROM table_name WHERE column_name > 1
# ```

# %% [markdown]
# ### Import data into DataFrame
# Example of how to read data into a DataFrame from a SQL statement
# ```Python
# import pandas as pd
#
# officers = pd.read_sql('SELECT * FROM officers', conn)
# ```

# %%
officer=pd.read_sql('SELECT * FROM OFFICERS',conn)

# %%
officer.head()
# Out:
#   case_number race gender  last_name first_name         full_name
# 0      44523A    L      M     Patino    Michael   Patino, Michael
# 1      44523A    W      M  Fillingim      Brian  Fillingim, Brian
# 2     121982X    L      M    Padilla    Gilbert  Padilla, Gilbert
# 3     605484T    W      M     Poston      Jerry     Poston, Jerry
# 4     384832T    B      M      Mondy    Michael    Mondy, Michael

# %%
incident=pd.read_sql('SELECT * FROM INCIDENTS',conn)

# %%
incident.head()
# Out:
#   case_number        date                  location subject_statuses  \
# 0      44523A  2013-02-23     3000 Chihuahua Street          Injured
# 1     121982X  2010-05-03  1300 N. Munger Boulevard          Injured
# 2     605484T  2007-08-12   200 S. Stemmons Freeway            Other
# 3     384832T  2007-05-26           7900 S. Loop 12   Shoot and Miss
# 4     244659R  2006-04-03        6512 South Loop 12          Injured
#
#   subject_weapon                                           subjects  \
# 0        Handgun                                   Curry, James L/M
# 1        Handgun                                Chavez, Gabriel L/M
# 2        Shotgun                                  Salinas, Nick L/M
# 3        Unarmed  Smith, James B/M; Dews, Antonio B/M; Spearman,...
# 4          Hands                                 Watkins, Caleb B/M
#
#    subject_count                                   officers  officer_count  \
# 0              1  Patino, Michael L/M; Fillingim, Brian W/M              2
# 1              1                       Padilla, Gilbert L/M              1
# 2              1                          Poston, Jerry W/M              1
# 3              3                         Mondy, Michael B/M              1
# 4              1                     Armstrong, Michael W/M              1
#
#   grand_jury_disposition attorney_general_forms_url  \
# 0                No Bill                       None
# 1                No Bill                       None
# 2            See Summary                       None
# 3                   None                       None
# 4                No Bill                       None
#
#                                          summary_url  \
# 0  http://dallaspolice.net/reports/OIS/narrative/...
# 1  http://dallaspolice.net/reports/OIS/narrative/...
# 2  http://dallaspolice.net/reports/OIS/narrative/...
# 3  http://dallaspolice.net/reports/OIS/narrative/...
# 4  http://dallaspolice.net/reports/OIS/narrative/...
#
#                                         summary_text  latitude  longitude
# 0  On Saturday, February 23, 2013, at approximate...       NaN        NaN
# 1  On Monday, May 3, 2010, at approximately 8:06 ...       NaN        NaN
# 2  On Sunday, August 12, 2007, at approximately 2...       NaN        NaN
# 3  On Saturday, May 26, 2007, at approximately 1:...       NaN        NaN
# 4  On Monday, April 3, 2006, at approximately 11:...       NaN        NaN

# %% [markdown]
# ### SQL join syntax
# `(INNER) JOIN`: returns records that have matching values in both tables
# ```SQL
# SELECT * FROM table_1 JOIN table_2 ON table_1.column_name_1=table_2.column_name_2
# ```
#
# `LEFT JOIN`: returns all records from the left table, and the matched records from the right table
# ```SQL
# SELECT * FROM table_1 LEFT JOIN table_2 ON table_1.column_name_1=table_2.column_name_2
# ```

# %%
merg=pd.read_sql("SELECT * FROM 'INCIDENTS' JOIN 'OFFICERS' ON INCIDENTS.case_number=OFFICERS.case_number",conn)

# %%
merg.set_index('case_number',inplace=True)

# %%
merg.head()
# Out:
#                           date                  location subject_statuses  \
# case_number
# (44523A, 44523A)    2013-02-23     3000 Chihuahua Street          Injured
# (44523A, 44523A)    2013-02-23     3000 Chihuahua Street          Injured
# (121982X, 121982X)  2010-05-03  1300 N. Munger Boulevard          Injured
# (605484T, 605484T)  2007-08-12   200 S. Stemmons Freeway            Other
# (384832T, 384832T)  2007-05-26           7900 S. Loop 12   Shoot and Miss
#
#                    subject_weapon  \
# case_number
# (44523A, 44523A)          Handgun
# (44523A, 44523A)          Handgun
# (121982X, 121982X)        Handgun
# (605484T, 605484T)        Shotgun
# (384832T, 384832T)        Unarmed
#
#                                                              subjects  \
# case_number
# (44523A, 44523A)                                     Curry, James L/M
# (44523A, 44523A)                                     Curry, James L/M
# (121982X, 121982X)                                Chavez, Gabriel L/M
# (605484T, 605484T)                                  Salinas, Nick L/M
# (384832T, 384832T)  Smith, James B/M; Dews, Antonio B/M; Spearman,...
#
#                     subject_count                                   officers  \
# case_number
# (44523A, 44523A)                1  Patino, Michael L/M; Fillingim, Brian W/M
# (44523A, 44523A)                1  Patino, Michael L/M; Fillingim, Brian W/M
# (121982X, 121982X)              1                       Padilla, Gilbert L/M
# (605484T, 605484T)              1                          Poston, Jerry W/M
# (384832T, 384832T)              3                         Mondy, Michael B/M
#
#                     officer_count grand_jury_disposition  \
# case_number
# (44523A, 44523A)                2                No Bill
# (44523A, 44523A)                2                No Bill
# (121982X, 121982X)              1                No Bill
# (605484T, 605484T)              1            See Summary
# (384832T, 384832T)              1                   None
#
#                    attorney_general_forms_url  \
# case_number
# (44523A, 44523A)                         None
# (44523A, 44523A)                         None
# (121982X, 121982X)                       None
# (605484T, 605484T)                       None
# (384832T, 384832T)                       None
#
#                                                           summary_url  \
# case_number
# (44523A, 44523A)    http://dallaspolice.net/reports/OIS/narrative/...
# (44523A, 44523A)    http://dallaspolice.net/reports/OIS/narrative/...
# (121982X, 121982X)  http://dallaspolice.net/reports/OIS/narrative/...
# (605484T, 605484T)  http://dallaspolice.net/reports/OIS/narrative/...
# (384832T, 384832T)  http://dallaspolice.net/reports/OIS/narrative/...
#
#                                                          summary_text  \
# case_number
# (44523A, 44523A)    On Saturday, February 23, 2013, at approximate...
# (44523A, 44523A)    On Saturday, February 23, 2013, at approximate...
# (121982X, 121982X)  On Monday, May 3, 2010, at approximately 8:06 ...
# (605484T, 605484T)  On Sunday, August 12, 2007, at approximately 2...
# (384832T, 384832T)  On Saturday, May 26, 2007, at approximately 1:...
#
#                     latitude  longitude race gender  last_name first_name  \
# case_number
# (44523A, 44523A)         NaN        NaN    L      M     Patino    Michael
# (44523A, 44523A)         NaN        NaN    W      M  Fillingim      Brian
# (121982X, 121982X)       NaN        NaN    L      M    Padilla    Gilbert
# (605484T, 605484T)       NaN        NaN    W      M     Poston      Jerry
# (384832T, 384832T)       NaN        NaN    B      M      Mondy    Michael
#
#                            full_name
# case_number
# (44523A, 44523A)     Patino, Michael
# (44523A, 44523A)    Fillingim, Brian
# (121982X, 121982X)  Padilla, Gilbert
# (605484T, 605484T)     Poston, Jerry
# (384832T, 384832T)    Mondy, Michael

# %%
merg_left=pd.read_sql("SELECT * FROM 'INCIDENTS' LEFT JOIN  'OFFICERS' ON INCIDENTS.case_number=OFFICERS.case_number",conn)

# %%
merg_left.head()
# Out:
#    case_number        date                  location subject_statuses  \
# 0       44523A  2013-02-23     3000 Chihuahua Street          Injured
# 1       44523A  2013-02-23     3000 Chihuahua Street          Injured
# 2      121982X  2010-05-03  1300 N. Munger Boulevard          Injured
# 3      605484T  2007-08-12   200 S. Stemmons Freeway            Other
# 4      384832T  2007-05-26           7900 S. Loop 12   Shoot and Miss
#
#   subject_weapon                                           subjects  \
# 0        Handgun                                   Curry, James L/M
# 1        Handgun                                   Curry, James L/M
# 2        Handgun                                Chavez, Gabriel L/M
# 3        Shotgun                                  Salinas, Nick L/M
# 4        Unarmed  Smith, James B/M; Dews, Antonio B/M; Spearman,...
#
#    subject_count                                   officers  officer_count  \
# 0              1  Patino, Michael L/M; Fillingim, Brian W/M              2
# 1              1  Patino, Michael L/M; Fillingim, Brian W/M              2
# 2              1                       Padilla, Gilbert L/M              1
# 3              1                          Poston, Jerry W/M              1
# 4              3                         Mondy, Michael B/M              1
#
#   grand_jury_disposition  ...  \
# 0                No Bill  ...
# 1                No Bill  ...
# 2                No Bill  ...
# 3            See Summary  ...
# 4                   None  ...
#
#                                          summary_url  \
# 0  http://dallaspolice.net/reports/OIS/narrative/...
# 1  http://dallaspolice.net/reports/OIS/narrative/...
# 2  http://dallaspolice.net/reports/OIS/narrative/...
# 3  http://dallaspolice.net/reports/OIS/narrative/...
# 4  http://dallaspolice.net/reports/OIS/narrative/...
#
#                                         summary_text latitude  longitude  \
# 0  On Saturday, February 23, 2013, at approximate...      NaN        NaN
# 1  On Saturday, February 23, 2013, at approximate...      NaN        NaN
# 2  On Monday, May 3, 2010, at approximately 8:06 ...      NaN        NaN
# 3  On Sunday, August 12, 2007, at approximately 2...      NaN        NaN
# 4  On Saturday, May 26, 2007, at approximately 1:...      NaN        NaN
#
#    case_number race gender  last_name first_name         full_name
# 0       44523A    L      M     Patino    Michael   Patino, Michael
# 1       44523A    W      M  Fillingim      Brian  Fillingim, Brian
# 2      121982X    L      M    Padilla    Gilbert  Padilla, Gilbert
# 3      605484T    W      M     Poston      Jerry     Poston, Jerry
# 4      384832T    B      M      Mondy    Michael    Mondy, Michael
#
# [5 rows x 21 columns]

# %%
merg_left.set_index('case_number',inplace=True)

# %%
merg_left.head()
# Out:
#                           date                  location subject_statuses  \
# case_number
# (44523A, 44523A)    2013-02-23     3000 Chihuahua Street          Injured
# (44523A, 44523A)    2013-02-23     3000 Chihuahua Street          Injured
# (121982X, 121982X)  2010-05-03  1300 N. Munger Boulevard          Injured
# (605484T, 605484T)  2007-08-12   200 S. Stemmons Freeway            Other
# (384832T, 384832T)  2007-05-26           7900 S. Loop 12   Shoot and Miss
#
#                    subject_weapon  \
# case_number
# (44523A, 44523A)          Handgun
# (44523A, 44523A)          Handgun
# (121982X, 121982X)        Handgun
# (605484T, 605484T)        Shotgun
# (384832T, 384832T)        Unarmed
#
#                                                              subjects  \
# case_number
# (44523A, 44523A)                                     Curry, James L/M
# (44523A, 44523A)                                     Curry, James L/M
# (121982X, 121982X)                                Chavez, Gabriel L/M
# (605484T, 605484T)                                  Salinas, Nick L/M
# (384832T, 384832T)  Smith, James B/M; Dews, Antonio B/M; Spearman,...
#
#                     subject_count                                   officers  \
# case_number
# (44523A, 44523A)                1  Patino, Michael L/M; Fillingim, Brian W/M
# (44523A, 44523A)                1  Patino, Michael L/M; Fillingim, Brian W/M
# (121982X, 121982X)              1                       Padilla, Gilbert L/M
# (605484T, 605484T)              1                          Poston, Jerry W/M
# (384832T, 384832T)              3                         Mondy, Michael B/M
#
#                     officer_count grand_jury_disposition  \
# case_number
# (44523A, 44523A)                2                No Bill
# (44523A, 44523A)                2                No Bill
# (121982X, 121982X)              1                No Bill
# (605484T, 605484T)              1            See Summary
# (384832T, 384832T)              1                   None
#
#                    attorney_general_forms_url  \
# case_number
# (44523A, 44523A)                         None
# (44523A, 44523A)                         None
# (121982X, 121982X)                       None
# (605484T, 605484T)                       None
# (384832T, 384832T)                       None
#
#                                                           summary_url  \
# case_number
# (44523A, 44523A)    http://dallaspolice.net/reports/OIS/narrative/...
# (44523A, 44523A)    http://dallaspolice.net/reports/OIS/narrative/...
# (121982X, 121982X)  http://dallaspolice.net/reports/OIS/narrative/...
# (605484T, 605484T)  http://dallaspolice.net/reports/OIS/narrative/...
# (384832T, 384832T)  http://dallaspolice.net/reports/OIS/narrative/...
#
#                                                          summary_text  \
# case_number
# (44523A, 44523A)    On Saturday, February 23, 2013, at approximate...
# (44523A, 44523A)    On Saturday, February 23, 2013, at approximate...
# (121982X, 121982X)  On Monday, May 3, 2010, at approximately 8:06 ...
# (605484T, 605484T)  On Sunday, August 12, 2007, at approximately 2...
# (384832T, 384832T)  On Saturday, May 26, 2007, at approximately 1:...
#
#                     latitude  longitude race gender  last_name first_name  \
# case_number
# (44523A, 44523A)         NaN        NaN    L      M     Patino    Michael
# (44523A, 44523A)         NaN        NaN    W      M  Fillingim      Brian
# (121982X, 121982X)       NaN        NaN    L      M    Padilla    Gilbert
# (605484T, 605484T)       NaN        NaN    W      M     Poston      Jerry
# (384832T, 384832T)       NaN        NaN    B      M      Mondy    Michael
#
#                            full_name
# case_number
# (44523A, 44523A)     Patino, Michael
# (44523A, 44523A)    Fillingim, Brian
# (121982X, 121982X)  Padilla, Gilbert
# (605484T, 605484T)     Poston, Jerry
# (384832T, 384832T)    Mondy, Michael
